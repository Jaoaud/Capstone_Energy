# %%
import pandas as pd

# %%
data_01 = {'01_Hour' : ['Bidirectional_LSTM_Multivariate_Horizon_Style_01H', 'CNN_Multivariate_Horizon_Style_01', 'Encoder_Decoder_LSTM_Multivariate_01H', 'GRU_Multivariate_Horizon_Style_01H', 'LSTM_Multivariate_Horizon_Style_01'], 'RMSE': [61.077, 92.173, 59.265, 67.318, 59.897],   'MAPE': [530.245, 1199.636, 599.143, 755.401, 256.849]}
data_03 = {'03_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_03H', 'CNN_Multivariate_Horizon_Style_03', 'Encoder_Decoder_LSTM_Multivariate_03H', 'GRU_Multivariate_Horizon_Style_03H', 'LSTM_Multivariate_Horizon_Style_03'], 'RMSE': [71.678, 85.569, 81.543, 79.343, 75.571],   'MAPE': [202.365, 192.139, 214.364, 231.438, 278.493]}
data_06 = {'06_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_06H', 'CNN_Multivariate_Horizon_Style_06', 'Encoder_Decoder_LSTM_Multivariate_06H', 'GRU_Multivariate_Horizon_Style_06H', 'LSTM_Multivariate_Horizon_Style_06'], 'RMSE': [72.452, 105.536, 95.123, 68.233, 107.665], 'MAPE': [111.797, 116.881, 129.068, 197.698, 105.959]}
data_12 = {'12_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_12H', 'CNN_Multivariate_Horizon_Style_12', 'Encoder_Decoder_LSTM_Multivariate_12H', 'GRU_Multivariate_Horizon_Style_12H', 'LSTM_Multivariate_Horizon_Style_12'], 'RMSE': [120.530, 148.615, 94.349, 76.381, 102.651],'MAPE': [104.422, 123.109, 103.826, 126.597, 94.833]}
data_24 = {'24_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_24H', 'CNN_Multivariate_Horizon_Style_24', 'Encoder_Decoder_LSTM_Multivariate_24H', 'GRU_Multivariate_Horizon_Style_24H', 'LSTM_Multivariate_Horizon_Style_24'], 'RMSE': [88.669, 87.217, 90.583, 79.144, 84.208],   'MAPE': [87.272, 87.639, 85.218, 115.611, 95.461]}

# %%
df_01 = pd.DataFrame(data_01)
df_03 = pd.DataFrame(data_03)
df_06 = pd.DataFrame(data_06)
df_12 = pd.DataFrame(data_12)
df_24 = pd.DataFrame(data_24)

# %%
df_01
# Out:
#                                              01_Hour    RMSE      MAPE
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_01H  61.077   530.245
# 1                  CNN_Multivariate_Horizon_Style_01  92.173  1199.636
# 2              Encoder_Decoder_LSTM_Multivariate_01H  59.265   599.143
# 3                 GRU_Multivariate_Horizon_Style_01H  67.318   755.401
# 4                 LSTM_Multivariate_Horizon_Style_01  59.897   256.849

# %%
result = pd.concat([df_01, df_03, df_06, df_12, df_24], axis=1)

# %%
result
# Out:
#                                              01_Hour    RMSE      MAPE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_01H  61.077   530.245
# 1                  CNN_Multivariate_Horizon_Style_01  92.173  1199.636
# 2              Encoder_Decoder_LSTM_Multivariate_01H  59.265   599.143
# 3                 GRU_Multivariate_Horizon_Style_01H  67.318   755.401
# 4                 LSTM_Multivariate_Horizon_Style_01  59.897   256.849
#
#                                             03_Hours    RMSE     MAPE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_03H  71.678  202.365
# 1                  CNN_Multivariate_Horizon_Style_03  85.569  192.139
# 2              Encoder_Decoder_LSTM_Multivariate_03H  81.543  214.364
# 3                 GRU_Multivariate_Horizon_Style_03H  79.343  231.438
# 4                 LSTM_Multivariate_Horizon_Style_03  75.571  278.493
#
#                                             06_Hours     RMSE     MAPE  \
# ...

# %%
data_01_rmse = {'01_Hour' : ['Bidirectional_LSTM_Multivariate_Horizon_Style_01H', 'CNN_Multivariate_Horizon_Style_01', 'Encoder_Decoder_LSTM_Multivariate_01H', 'GRU_Multivariate_Horizon_Style_01H', 'LSTM_Multivariate_Horizon_Style_01'], 'RMSE': [61.077, 92.173, 59.265, 67.318, 59.897]}
data_03_rmse = {'03_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_03H', 'CNN_Multivariate_Horizon_Style_03', 'Encoder_Decoder_LSTM_Multivariate_03H', 'GRU_Multivariate_Horizon_Style_03H', 'LSTM_Multivariate_Horizon_Style_03'], 'RMSE': [71.678, 85.569, 81.543, 79.343, 75.571]}
data_06_rmse = {'06_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_06H', 'CNN_Multivariate_Horizon_Style_06', 'Encoder_Decoder_LSTM_Multivariate_06H', 'GRU_Multivariate_Horizon_Style_06H', 'LSTM_Multivariate_Horizon_Style_06'], 'RMSE': [72.452, 105.536, 95.123, 68.233, 107.665]}
data_12_rmse = {'12_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_12H', 'CNN_Multivariate_Horizon_Style_12', 'Encoder_Decoder_LSTM_Multivariate_12H', 'GRU_Multivariate_Horizon_Style_12H', 'LSTM_Multivariate_Horizon_Style_12'], 'RMSE': [120.530, 148.615, 94.349, 76.381, 102.651]}
data_24_rmse = {'24_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_24H', 'CNN_Multivariate_Horizon_Style_24', 'Encoder_Decoder_LSTM_Multivariate_24H', 'GRU_Multivariate_Horizon_Style_24H', 'LSTM_Multivariate_Horizon_Style_24'], 'RMSE': [88.669, 87.217, 90.583, 79.144, 84.208]}

data_01_mape = {'01_Hour' : ['Bidirectional_LSTM_Multivariate_Horizon_Style_01H', 'CNN_Multivariate_Horizon_Style_01', 'Encoder_Decoder_LSTM_Multivariate_01H', 'GRU_Multivariate_Horizon_Style_01H', 'LSTM_Multivariate_Horizon_Style_01'], 'MAPE': [530.245, 1199.636, 599.143, 755.401, 256.849]}
data_03_mape = {'03_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_03H', 'CNN_Multivariate_Horizon_Style_03', 'Encoder_Decoder_LSTM_Multivariate_03H', 'GRU_Multivariate_Horizon_Style_03H', 'LSTM_Multivariate_Horizon_Style_03'], 'MAPE': [202.365, 192.139, 214.364, 231.438, 278.493]}
data_06_mape = {'06_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_06H', 'CNN_Multivariate_Horizon_Style_06', 'Encoder_Decoder_LSTM_Multivariate_06H', 'GRU_Multivariate_Horizon_Style_06H', 'LSTM_Multivariate_Horizon_Style_06'], 'MAPE': [111.797, 116.881, 129.068, 197.698, 105.959]}
data_12_mape = {'12_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_12H', 'CNN_Multivariate_Horizon_Style_12', 'Encoder_Decoder_LSTM_Multivariate_12H', 'GRU_Multivariate_Horizon_Style_12H', 'LSTM_Multivariate_Horizon_Style_12'], 'MAPE': [104.422, 123.109, 103.826, 126.597, 94.833]}
data_24_mape = {'24_Hours': ['Bidirectional_LSTM_Multivariate_Horizon_Style_24H', 'CNN_Multivariate_Horizon_Style_24', 'Encoder_Decoder_LSTM_Multivariate_24H', 'GRU_Multivariate_Horizon_Style_24H', 'LSTM_Multivariate_Horizon_Style_24'], 'MAPE': [87.272, 87.639, 85.218, 115.611, 95.461]}

# %%
df_01_rmse = pd.DataFrame(data_01_rmse)
df_03_rmse = pd.DataFrame(data_03_rmse)
df_06_rmse = pd.DataFrame(data_06_rmse)
df_12_rmse = pd.DataFrame(data_12_rmse)
df_24_rmse = pd.DataFrame(data_24_rmse)

df_01_mape = pd.DataFrame(data_01_mape)
df_03_mape = pd.DataFrame(data_03_mape)
df_06_mape = pd.DataFrame(data_06_mape)
df_12_mape = pd.DataFrame(data_12_mape)
df_24_mape = pd.DataFrame(data_24_mape)

# %%
result_1 = pd.concat([df_01_rmse, df_03_rmse, df_06_rmse, df_12_rmse, df_24_rmse], axis=1)
result_2 = pd.concat([df_01_mape, df_03_mape, df_06_mape, df_12_mape, df_24_mape], axis=1)

# %%
result_1
# Out:
#                                              01_Hour    RMSE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_01H  61.077
# 1                  CNN_Multivariate_Horizon_Style_01  92.173
# 2              Encoder_Decoder_LSTM_Multivariate_01H  59.265
# 3                 GRU_Multivariate_Horizon_Style_01H  67.318
# 4                 LSTM_Multivariate_Horizon_Style_01  59.897
#
#                                             03_Hours    RMSE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_03H  71.678
# 1                  CNN_Multivariate_Horizon_Style_03  85.569
# 2              Encoder_Decoder_LSTM_Multivariate_03H  81.543
# 3                 GRU_Multivariate_Horizon_Style_03H  79.343
# 4                 LSTM_Multivariate_Horizon_Style_03  75.571
#
#                                             06_Hours     RMSE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_06H   72.452
# 1                  CNN_Multivariate_Horizon_Style_06  105.536
# ...

# %%
result_2
# Out:
#                                              01_Hour      MAPE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_01H   530.245
# 1                  CNN_Multivariate_Horizon_Style_01  1199.636
# 2              Encoder_Decoder_LSTM_Multivariate_01H   599.143
# 3                 GRU_Multivariate_Horizon_Style_01H   755.401
# 4                 LSTM_Multivariate_Horizon_Style_01   256.849
#
#                                             03_Hours     MAPE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_03H  202.365
# 1                  CNN_Multivariate_Horizon_Style_03  192.139
# 2              Encoder_Decoder_LSTM_Multivariate_03H  214.364
# 3                 GRU_Multivariate_Horizon_Style_03H  231.438
# 4                 LSTM_Multivariate_Horizon_Style_03  278.493
#
#                                             06_Hours     MAPE  \
# 0  Bidirectional_LSTM_Multivariate_Horizon_Style_06H  111.797
# 1                  CNN_Multivariate_Horizon_Style_06  116.881
# ...
